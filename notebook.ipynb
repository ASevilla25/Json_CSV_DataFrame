# %%
import pandas as pd

# %%
import numpy as np

# %%
df1 = pd.read_csv('info_academica.csv')

# %%
df1
# Out:
#     id_alumno nombre_alumno apellido_alumno           carrera    facultad  \
# 0           1       Alfonso         Sevilla  Ing. en sistemas  Ingenieria
# 1           2        Carmen          Zepeda          Economia    Economia
# 2           3        Carlos         Sevilla        Ecoturismo  Ecoturismo
# 3           4         Karen            Cruz          Medicina    Medicina
# 4           5         Maria           Ortiz            Letras      Social
# 5           6         Choco          Lozano    Trabajo social      Social
# 6           7           Bad           Bunny            Musica        Arte
# 7           8        Leonel           Messi      Educ. Fisica      Social
# 8           9      Salvador        Nasralla        Ing. Civil  Ingenieria
# 9          10     Cristiano         Ronaldo  Ing. en sistemas  Ingenieria
# 10         11        Neymar              Jr        Ecoturismo  Ecoturismo
# 11         12         Karol               G            Musica        Arte
# ...

# %%
df2 = pd.read_json('info_acadecima_estudiante.json')

# %%
df2
# Out:
#     id_alumno nombre_alumno     nom_materia  nota_final
# 0           1       Alfonso    programacion          90
# 1           2        Carmen  administracion          56
# 2           3        Carlos      publicidad          70
# 3           4         Karen        biologia          46
# 4           5         Maria         español          87
# 5           6         Choco      sociologia          78
# 6           7           Bad        musica-1          14
# 7           8        Leonel     futbol sala          77
# 8           9      Salvador          dibujo          74
# 9          10     Cristiano      algoritmos          87
# 10         11        Neymar          ingles          85
# 11         12         Karol        musica-1          35
# 12         13          Bill    programacion          67
# 13         14       Xiomara         cirugia          65
# 14         15    Ronaldinho      baloncesto          64
# 15         16          Noel  administracion          92
# ...

# %%
df = df1.merge(df2)

# %%
df
# Out:
#     id_alumno nombre_alumno apellido_alumno           carrera    facultad  \
# 0           1       Alfonso         Sevilla  Ing. en sistemas  Ingenieria
# 1           2        Carmen          Zepeda          Economia    Economia
# 2           3        Carlos         Sevilla        Ecoturismo  Ecoturismo
# 3           4         Karen            Cruz          Medicina    Medicina
# 4           5         Maria           Ortiz            Letras      Social
# 5           6         Choco          Lozano    Trabajo social      Social
# 6           7           Bad           Bunny            Musica        Arte
# 7           8        Leonel           Messi      Educ. Fisica      Social
# 8           9      Salvador        Nasralla        Ing. Civil  Ingenieria
# 9          10     Cristiano         Ronaldo  Ing. en sistemas  Ingenieria
# 10         11        Neymar              Jr        Ecoturismo  Ecoturismo
# 11         12         Karol               G            Musica        Arte
# ...

# %%
df["carrera"]=='Ing. en sistemas'
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# Name: carrera, dtype: bool

# %%
""""carrera con mejores promedios a nivel periodo"""
df.groupby(['periodo', 'carrera']).nota_final.mean().max()
# Out:
# 88.5

# %%
df.groupby(['año']).nota_final<=65
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [169], in <cell line: 1>()
# ----> 1 df.groupby(['año']).nota_final<=65
#
# TypeError: '<=' not supported between instances of 'SeriesGroupBy' and 'int'
